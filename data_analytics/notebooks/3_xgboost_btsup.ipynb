# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import mlflow
import mlflow.xgboost
from sklearn.feature_selection import SelectFromModel
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.metrics import r2_score
from itertools import product

warnings.filterwarnings('ignore')

TARGET= 'consommation_telerelevee_btsup'

OTHERS= [
    'consommation_telerelevee_hta',
    'consommation_telerelevee_professionnelle',
    'consommation_telerelevee_residentielle',
]

HORIZON=7*48

# %%
df=pd.read_csv("C:/Users/T14s/Desktop/ml-project/data/features_with_lags.csv",parse_dates=['datetime'])
df = df.set_index('datetime')

# %%
featurs_col=['year_utc', 'month_utc', 'day', 'day_of_week', 'est_weekend',
       'est_ferie', 'hour_utc', 'minute_utc', 'temperature_reelle_lissee',
       'temperature_normale_lissee', 'ecart_temperature', 'temp_x_weekend',
       'temp_x_ferier', 'degre_jour_chauffage', 'degre_jour_clim','jour_fetes',
       'pseudo_rayonnement','consommation_telerelevee_btsup_lag_336',
       'consommation_telerelevee_btsup_lag_672',
       'consommation_telerelevee_btsup_lag_1344',]
target='consommation_telerelevee_btsup'

# %%
X=df[featurs_col]
y=df[target]

# %%
X_train_full= X.iloc[:-HORIZON]  
X_test= X.iloc[-HORIZON:]   
y_train_full= y.iloc[:-HORIZON]
y_test= y.iloc[-HORIZON:]

# %%
print('Features finales :', featurs_col)
print('Nombre :', len(featurs_col))

X_train_final= X_train_full[featurs_col]
X_test_final= X_test[featurs_col]
# Out:
# Features finales : ['year_utc', 'month_utc', 'day', 'day_of_week', 'est_weekend', 'est_ferie', 'hour_utc', 'minute_utc', 'temperature_reelle_lissee', 'temperature_normale_lissee', 'ecart_temperature', 'temp_x_weekend', 'temp_x_ferier', 'degre_jour_chauffage', 'degre_jour_clim', 'jour_fetes', 'pseudo_rayonnement', 'consommation_telerelevee_btsup_lag_336', 'consommation_telerelevee_btsup_lag_672', 'consommation_telerelevee_btsup_lag_1344']
# Nombre : 20

# %%
PARAM_GRID = {
    'n_estimators' : [300, 500],
    'max_depth'    : [4, 6],
    'learning_rate': [0.05, 0.1],
    'subsample'    : [0.8, 1.0],
}

keys= list(PARAM_GRID.keys())
values= list(PARAM_GRID.values())
combinations= [dict(zip(keys, v)) for v in product(*values)]

tscv = TimeSeriesSplit(
    n_splits=5,
    test_size=HORIZON 
)

mlflow.set_tracking_uri("http://127.0.0.1:5000")

mlflow.set_experiment('XGBoost_btsup01')

best_mae= float('inf')
best_params= None
results= []

for i, params in enumerate(combinations):

    fold_maes= []
    fold_rmses= []

    for fold, (train_idx, val_idx) in enumerate(tscv.split(X_train_final)):

        X_cv_train= X_train_final.iloc[train_idx]
        y_cv_train= y_train_full.iloc[train_idx]
        X_cv_val= X_train_final.iloc[val_idx]
        y_cv_val= y_train_full.iloc[val_idx]

        model = XGBRegressor(
            **params,
            random_state=42,
            n_jobs=-1
        )
        model.fit(
            X_cv_train, y_cv_train,
            eval_set=[(X_cv_val, y_cv_val)],
            verbose=False
        )

        preds = model.predict(X_cv_val)
        fold_maes.append(mean_absolute_error(y_cv_val, preds))
        fold_rmses.append(np.sqrt(mean_squared_error(y_cv_val, preds)))

    mae_mean  = np.mean(fold_maes)
    mae_std   = np.std(fold_maes)
    rmse_mean = np.mean(fold_rmses)

    results.append({**params, 'mae_mean': mae_mean, 'mae_std': mae_std})

    with mlflow.start_run(run_name=f'run_{i+1:02d}'):
        mlflow.log_params(params)
        mlflow.log_param('target', TARGET)
        mlflow.log_param('n_features_selected', len(featurs_col))
        mlflow.log_param('horizon', 'J+7')

        mlflow.log_metric('cv_mae_mean', mae_mean)
        mlflow.log_metric('cv_mae_std', mae_std)
        mlflow.log_metric('cv_rmse_mean', rmse_mean)

        for f, m in enumerate(fold_maes):
            mlflow.log_metric(f'fold_{f+1}_mae', m)

    if mae_mean < best_mae:
        best_mae= mae_mean
        best_params= params

    print(f'  [{i+1:2d}/{len(combinations)}] MAE={mae_mean:.2f} ± {mae_std:.2f} | {params}')

print(f'\nGrid Search terminé')
print(f'Meilleurs paramètres: {best_params}')
print(f'Meilleure MAE CV: {best_mae:.2f}')
# Out:
# 🏃 View run run_01 at: http://127.0.0.1:5000/#/experiments/3/runs/72bc32f44fa946fc89510c9257517126
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#   [ 1/16] MAE=265567520.00 ± 103457012.84 | {'n_estimators': 300, 'max_depth': 4, 'learning_rate': 0.05, 'subsample': 0.8}
# 🏃 View run run_02 at: http://127.0.0.1:5000/#/experiments/3/runs/dc9ad27d21fe4a8bb22d8b57e55523d8
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#   [ 2/16] MAE=265141497.60 ± 100806292.99 | {'n_estimators': 300, 'max_depth': 4, 'learning_rate': 0.05, 'subsample': 1.0}
# 🏃 View run run_03 at: http://127.0.0.1:5000/#/experiments/3/runs/80551836551744e8a5b9a638923600af
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#   [ 3/16] MAE=236397702.40 ± 92186920.13 | {'n_estimators': 300, 'max_depth': 4, 'learning_rate': 0.1, 'subsample': 0.8}
# 🏃 View run run_04 at: http://127.0.0.1:5000/#/experiments/3/runs/5c587530399d4695ab47c886b42550e4
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#   [ 4/16] MAE=232831257.60 ± 93327301.56 | {'n_estimators': 300, 'max_depth': 4, 'learning_rate': 0.1, 'subsample': 1.0}
# 🏃 View run run_05 at: http://127.0.0.1:5000/#/experiments/3/runs/75a5089be6cd4e54ad6b9b511716d9f2
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#   [ 5/16] MAE=226350550.40 ± 90728664.49 | {'n_estimators': 300, 'max_depth': 6, 'learning_rate': 0.05, 'subsample': 0.8}
# 🏃 View run run_06 at: http://127.0.0.1:5000/#/experiments/3/runs/baa13d3f735a435f8c4d5d314a7cc391
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#   [ 6/16] MAE=239359990.40 ± 107840299.49 | {'n_estimators': 300, 'max_depth': 6, 'learning_rate': 0.05, 'subsample': 1.0}
# 🏃 View run run_07 at: http://127.0.0.1:5000/#/experiments/3/runs/7703b783cf3045508f75917b7196fc22
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#   [ 7/16] MAE=200128964.80 ± 75686388.76 | {'n_estimators': 300, 'max_depth': 6, 'learning_rate': 0.1, 'subsample': 0.8}
# 🏃 View run run_08 at: http://127.0.0.1:5000/#/experiments/3/runs/8c872424ab8f4ae588de665cfadb8330
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#   [ 8/16] MAE=197174721.60 ± 81887237.28 | {'n_estimators': 300, 'max_depth': 6, 'learning_rate': 0.1, 'subsample': 1.0}
# 🏃 View run run_09 at: http://127.0.0.1:5000/#/experiments/3/runs/40a3c3ec691d43459fffa8b32269f3ee
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#   [ 9/16] MAE=249702243.20 ± 94617544.60 | {'n_estimators': 500, 'max_depth': 4, 'learning_rate': 0.05, 'subsample': 0.8}
# 🏃 View run run_10 at: http://127.0.0.1:5000/#/experiments/3/runs/0f57726eadf6488b9f1a228717f2a189
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#   [10/16] MAE=247121539.20 ± 88322713.30 | {'n_estimators': 500, 'max_depth': 4, 'learning_rate': 0.05, 'subsample': 1.0}
# 🏃 View run run_11 at: http://127.0.0.1:5000/#/experiments/3/runs/3913fbb849b6436ba430da40c572435f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#   [11/16] MAE=220839467.20 ± 86025840.01 | {'n_estimators': 500, 'max_depth': 4, 'learning_rate': 0.1, 'subsample': 0.8}
# 🏃 View run run_12 at: http://127.0.0.1:5000/#/experiments/3/runs/75f846866f2448efa5b79dd00cff04ae
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#   [12/16] MAE=211574976.00 ± 70321691.12 | {'n_estimators': 500, 'max_depth': 4, 'learning_rate': 0.1, 'subsample': 1.0}
# 🏃 View run run_13 at: http://127.0.0.1:5000/#/experiments/3/runs/3dfd64f4c403469b9df61db952bfc4c8
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#   [13/16] MAE=203687560.00 ± 73477415.96 | {'n_estimators': 500, 'max_depth': 6, 'learning_rate': 0.05, 'subsample': 0.8}
# 🏃 View run run_14 at: http://127.0.0.1:5000/#/experiments/3/runs/cc7b8c3d7e3143f88d9edd5dbd4e43a6
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#   [14/16] MAE=222098779.20 ± 93049447.64 | {'n_estimators': 500, 'max_depth': 6, 'learning_rate': 0.05, 'subsample': 1.0}
# 🏃 View run run_15 at: http://127.0.0.1:5000/#/experiments/3/runs/082dfc8390004d6ab74eae43595ba3f7
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#   [15/16] MAE=185056545.60 ± 71544260.45 | {'n_estimators': 500, 'max_depth': 6, 'learning_rate': 0.1, 'subsample': 0.8}
# 🏃 View run run_16 at: http://127.0.0.1:5000/#/experiments/3/runs/31470de87a1a4ab9a7b6106c1434392b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
#   [16/16] MAE=181410872.00 ± 72842820.52 | {'n_estimators': 500, 'max_depth': 6, 'learning_rate': 0.1, 'subsample': 1.0}
#
# Grid Search terminé
# Meilleurs paramètres: {'n_estimators': 500, 'max_depth': 6, 'learning_rate': 0.1, 'subsample': 1.0}
# Meilleure MAE CV: 181410872.00

# %%
from mlflow.models.signature import infer_signature
from mlflow.tracking import MlflowClient

final_model = XGBRegressor(**best_params, random_state=42, n_jobs=-1)
final_model.fit(X_train_final, y_train_full)

y_pred= final_model.predict(X_test_final)
y_true_arr = np.array(y_test).flatten()
y_pred_arr = np.array(y_pred).flatten()

mae= mean_absolute_error(y_true_arr, y_pred_arr)
rmse= np.sqrt(mean_squared_error(y_true_arr, y_pred_arr))
mape= np.mean(np.abs((y_true_arr - y_pred_arr) / y_true_arr)) * 100
r2= r2_score(y_true_arr, y_pred_arr)

print(f'MAE: {mae:,.0f}')
print(f'RMSE: {rmse:,.0f}')
print(f'MAPE: {mape:.2f}%')
print(f'R2: {r2:.4f}')

signature = infer_signature(
    model_input=X_train_final,
    model_output=final_model.predict(X_train_final)
)

with mlflow.start_run(run_name='FINAL_best_model') as run:
    final_run_id = run.info.run_id

    mlflow.set_tag("segment","btsup")
    mlflow.set_tag("statut","production")
    mlflow.set_tag("horizon","J+7")
    mlflow.set_tag("vs_sarima_mape","-67%")
    mlflow.set_tag("n_features",len(featurs_col))

    mlflow.log_params(best_params)
    mlflow.log_param('target',TARGET)
    mlflow.log_param('features_selected',str(featurs_col))
    mlflow.log_param('n_features_selected', len(featurs_col))
    mlflow.log_param('horizon','J+7')

    mlflow.log_metric('test_mae',mae)
    mlflow.log_metric('test_rmse',rmse)
    mlflow.log_metric('test_mape',mape)
    mlflow.log_metric('test_r2',r2)
    mlflow.log_metric('cv_mae_best',best_mae)

    mlflow.xgboost.log_model(
        xgb_model=final_model,
        artifact_path="model",
        signature=signature,
        input_example=X_test_final.iloc[:3]
    )

fig, ax = plt.subplots(figsize=(14, 4))
ax.plot(y_test.index, y_true_arr, color='steelblue', label='Reel', linewidth=1.5)
ax.plot(y_test.index, y_pred_arr, color='red', label='Prédit (J+7)',
        linewidth=1.5, linestyle='--')
ax.set_title(f'Prédictions vs Réel — btsup · Test J+7\n'
             f'MAE={mae:,.0f} | RMSE={rmse:,.0f} | MAPE={mape:.1f}%',
             fontweight='bold')
ax.legend()
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig("predictions_btsup.png", dpi=120, bbox_inches='tight')
plt.show()

with mlflow.start_run(run_id=final_run_id):
    mlflow.log_artifact("predictions_btsup.png")

client = MlflowClient()
registered = mlflow.register_model(f"runs:/{final_run_id}/model", "Enedis_btsup")
client.transition_model_version_stage(
    name="Enedis_btsup",
    version=registered.version,
    stage="Production"
)
# Out:
# MAE: 237,077,600
# RMSE: 389,569,380
# MAPE: 4.34%
# R2: 0.7962
# 2026/04/12 21:17:51 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# 🏃 View run FINAL_best_model at: http://127.0.0.1:5000/#/experiments/3/runs/0c1ce6fc2f334b4b88d872c58c854455
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
# Registered model 'Enedis_btsup' already exists. Creating a new version of this model...
# 2026/04/12 21:17:57 WARNING mlflow.tracking._model_registry.fluent: Run with id 0c1ce6fc2f334b4b88d872c58c854455 has no artifacts at artifact path 'model', registering model based on models:/m-17867c5b673140deb408c749fff4e3bf instead
# 🏃 View run FINAL_best_model at: http://127.0.0.1:5000/#/experiments/3/runs/0c1ce6fc2f334b4b88d872c58c854455
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
# 2026/04/12 21:17:57 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: Enedis_btsup, version 7
# Created version '7' of model 'Enedis_btsup'.
# <ModelVersion: aliases=[], creation_timestamp=1776025077198, current_stage='Production', deployment_job_state=<ModelVersionDeploymentJobState: current_task_name='', job_id='', job_state='DEPLOYMENT_JOB_CONNECTION_STATE_UNSPECIFIED', run_id='', run_state='DEPLOYMENT_JOB_RUN_STATE_UNSPECIFIED'>, description='', last_updated_timestamp=1776025077262, metrics=None, model_id=None, name='Enedis_btsup', params=None, run_id='0c1ce6fc2f334b4b88d872c58c854455', run_link='', source='models:/m-17867c5b673140deb408c749fff4e3bf', status='READY', status_message=None, tags={}, user_id='', version='7', workspace='default'>

# %%
final_model = XGBRegressor(**best_params, random_state=42, n_jobs=-1)
final_model.fit(X_train_final, y_train_full)

y_pred= final_model.predict(X_test_final)
y_true_arr = np.array(y_test).flatten()
y_pred_arr = np.array(y_pred).flatten()

mae= mean_absolute_error(y_true_arr, y_pred_arr)
rmse= np.sqrt(mean_squared_error(y_true_arr, y_pred_arr))
mape= np.mean(np.abs((y_true_arr - y_pred_arr) / y_true_arr)) * 100
r2= r2_score(y_true_arr, y_pred_arr)

print(f'MAE: {mae:,.0f}')
print(f'RMSE: {rmse:,.0f}')
print(f'MAPE: {mape:.2f}%')
print(f'R2: {r2:.4f}')

with mlflow.start_run(run_name='FINAL_best_model'):
    mlflow.log_params(best_params)
    mlflow.log_param('target', TARGET)
    mlflow.log_param('n_features_selected', len(featurs_col))
    mlflow.log_param('features_selected', str(featurs_col))
    mlflow.log_param('horizon', 'J+7')

    mlflow.log_metric('test_mae', mae)
    mlflow.log_metric('test_rmse', rmse)
    mlflow.log_metric('test_mape', mape)
    mlflow.log_metric('cv_mae_best', best_mae)

    mlflow.xgboost.log_model(final_model, 'model')

fig, ax = plt.subplots(figsize=(14, 5))

ax.plot(y_test.index, y_test.values, 
        label='Réel', color='steelblue', linewidth=1.5)
ax.plot(y_test.index, y_pred, 
        label='Prédit (J+7)', color='red', linewidth=1.5, linestyle='--')

ax.set_title(f'Prédictions vs Reel — btsup · Test J+7\n'
             f'MAE={mae:,.0f} | RMSE={rmse:,.0f} | MAPE={mape:.1f}%',
             fontweight='bold')
ax.legend()
ax.grid(alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# 2026/04/12 21:17:17 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# MAE: 237,077,600
# RMSE: 389,569,380
# MAPE: 4.34%
# R2: 0.7962
# 🏃 View run FINAL_best_model at: http://127.0.0.1:5000/#/experiments/3/runs/62118ab15f164ed88b0c94c0384774af
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/3
